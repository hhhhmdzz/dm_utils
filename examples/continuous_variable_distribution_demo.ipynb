# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer as load_data
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

# %%
x, y = load_data(return_X_y=True, as_frame=True)
data = pd.concat((x, y), axis=1)
train, test = train_test_split(data, test_size=0.2, random_state=42)
test_wo_target = test.drop(columns=['target'])

# %%
from dm_utils.utils.feas import cont_var_dist

# %%
figs = cont_var_dist(train, test_wo_target, ncol=None, plot_kde=True, plot_hist=True, return_figs=True, show_img=False)
figs[0]

# %%
cont_var_dist(train.iloc[:, :10], test_wo_target.iloc[:, :10], ncol=5, plot_kde=True, plot_hist=False)

# %%
cont_var_dist(train.iloc[:, :10], test_wo_target.iloc[:, :10], ncol=5, plot_kde=False, plot_hist=True)

# %%
cont_var_dist(train.iloc[:, :10], test_wo_target.iloc[:, :10], ncol=5, plot_kde=False, plot_hist=True, hist_multiple='layer')

# %%
cont_var_dist(train.iloc[:, :10], None, ncol=5, plot_kde=True, plot_hist=True, return_figs=False, show_img=True)
